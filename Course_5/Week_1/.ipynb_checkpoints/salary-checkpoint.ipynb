# %%
# %pylab inline
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from itertools import product

def invboxcox(y,lmbda):
   if lmbda == 0:
      return(np.exp(y))
   else:
      return(np.exp(np.log(lmbda*y+1)/lmbda))
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("WAG_C_M.csv", sep = ";", index_col = "month")
df.head()
# Out:
#             WAG_C_M
# month
# 01.01.1993     15.3
# 01.02.1993     19.1
# 01.03.1993     23.6
# 01.04.1993     30.6
# 01.05.1993     37.5

# %% [markdown]
# # 1. Визуальный анализ ряда

# %%
df.plot()

# %% [markdown]
# Можно увидеть, что у ряда присутствует тренд, сезонность и возрастающая дисперсия.

# %% [markdown]
# # 2. Стабилизация дисперсии

# %%
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(df.WAG_C_M)[1])
# Out:
# Критерий Дики-Фуллера: p=0.991850

# %%
df['sl_box'], lmbda = stats.boxcox(df.WAG_C_M)
plt.figure(figsize = (15,7))
df.sl_box.plot()
plt.ylabel(u'Transformed salary')
print("Оптимальный параметр преобразования Бокса-Кокса: %f" % lmbda)
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(df.sl_box)[1])
# Out:
# Оптимальный параметр преобразования Бокса-Кокса: 0.263202
# Критерий Дики-Фуллера: p=0.696899

# %% [markdown]
# Отвергать нестационарность нельзя.

# %% [markdown]
# # 3. Выбор порядка дифференцирования

# %% [markdown]
# Попробуем обычное дифферинцирование

# %%
df["sl_diff"] = df['sl_box']-df['sl_box'].shift(1)
plt.figure(figsize = (15,7))
df.sl_diff.plot()
df["sl_diff"][0]
# Out:
# nan

# %% [markdown]
# По графику видна возрастающая дисперсия. Попробуем сезонное дифферинцирование.

# %%
df["sl_diff"] = df['sl_box']-df['sl_box'].shift(12)
plt.figure(figsize = (15,7))
df.sl_diff.plot()

# %% [markdown]
# Виден некоторый тренд. Попробуем сезонное дифференцирование, а потом обычное.

# %%
df["sl_diff"] = df['sl_box']-df['sl_box'].shift(12)
df["sl_diff"] = df["sl_diff"]-df["sl_diff"].shift(1)
plt.figure(figsize = (15,7))
df.sl_diff.plot()

# %% [markdown]
# Ряд похож на стационарный.

# %%
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(df.sl_diff[13:])[1])
# Out:
# Критерий Дики-Фуллера: p=0.000000

# %% [markdown]
# Гипотеза о нестационарности отвергается.

# %% [markdown]
# # 4. Выбор начальных приближений для p, q, P, Q

# %% [markdown]
# Построим графики автокорреляции и частичной автокорреляции.

# %%
plt.figure(figsize = (15,12))
ax = plt.subplot(211)
sm.graphics.tsa.plot_acf(df.sl_diff[13:].values.squeeze(), lags=48, ax=ax)
pylab.show()
plt.figure(figsize = (15,24))
ax = plt.subplot(212)
sm.graphics.tsa.plot_pacf(df.sl_diff[13:].values.squeeze(), lags=48, ax=ax)
pylab.show()

# %% [markdown]
# Начальные приближения: Q=0, q=5, P=4, p=10

# %% [markdown]
# # 5.Обучение и сравнение моделей-кандидатов, выбор победителя

# %%
ps = range(0, 11)
d=1
qs = range(0, 6)
Ps = range(0, 5)
D=1
Qs = range(0, 1)

# %%
parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)
# Out:
# 330

# %%
# %%time
results = []
best_aic = float("inf")
warnings.filterwarnings('ignore')

for param in parameters_list:
    #try except нужен, потому что на некоторых наборах параметров модель не обучается
    try:
        model=sm.tsa.statespace.SARIMAX(df.sl_box, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
    #выводим параметры, на которых модель не обучается и переходим к следующему набору
    except ValueError:
        print('wrong parameters:', param)
        continue
    aic = model.aic
    #сохраняем лучшую модель, aic, параметры
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
    
warnings.filterwarnings('default')
# Out:
# Wall time: 51min 40s

# %%
result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
# Out:
#        parameters        aic
# 176  (5, 5, 1, 0) -24.844791
# 201  (6, 4, 1, 0) -24.767002
# 177  (5, 5, 2, 0) -23.485551
# 206  (6, 5, 1, 0) -22.609846
# 146  (4, 5, 1, 0) -22.516195

# %%
print(best_model.summary())
# Out:
#                                  Statespace Model Results
# ...
# Dep. Variable:                             sl_box   No. Observations:                  284
# Model:             SARIMAX(5, 1, 5)x(1, 1, 0, 12)   Log Likelihood                  24.422
# Date:                            Tue, 11 Feb 2020   AIC                            -24.845
# Time:                                    15:07:49   BIC                             18.381
# Sample:                                         0   HQIC                            -7.489
#                                             - 284
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2253      0.551     -0.409      0.683      -1.306       0.855
# ar.L2          0.2358      0.383      0.615      0.539      -0.516       0.987
# ...

# %% [markdown]
# Лучшая модель p = 5, q = 5, P = 1, Q = 0

# %% [markdown]
# # 6.Анализ остатков построенной модели

# %%
plt.figure(figsize(15,8))
plt.subplot(211)
best_model.resid[13:].plot()
plt.ylabel(u'Residuals')

ax = plt.subplot(212)
sm.graphics.tsa.plot_acf(best_model.resid[13:].values.squeeze(), lags=48, ax=ax)

print("Критерий Стьюдента: p=%f" % stats.ttest_1samp(best_model.resid[13:], 0)[1])
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(best_model.resid[13:])[1])
# Out:
# Критерий Стьюдента: p=0.159895
# Критерий Дики-Фуллера: p=0.000000

# %% [markdown]
# Остатки не смещены, стационарны, неавтокоррелированы.

# %%
df['model'] = invboxcox(best_model.fittedvalues, lmbda)
plt.figure(figsize(15,7))
df.WAG_C_M[13:].plot()
df.model[13:].plot(color='r')
plt.ylabel('Wine sales')
pylab.show()

# %% [markdown]
# # 7.Прогнозирование с помощью финальной модели.

# %%
WAG_C_M2 = df[['WAG_C_M']]
date_list = [datetime.datetime.strptime("01.08.2016", "%d.%m.%Y").date() + relativedelta(months=x) for x in range(1,37)]
future = pd.DataFrame(index=date_list, columns= WAG_C_M2.columns)
WAG_C_M2 = pd.concat([WAG_C_M2, future])
WAG_C_M2["forecast"] = np.nan
WAG_C_M2.forecast[284:(284+36)] = invboxcox(best_model.predict(start=284, end=284+35), lmbda).values

plt.figure(figsize = (15,7))
WAG_C_M2.WAG_C_M.plot()
WAG_C_M2.forecast.plot(color='r')
plt.ylabel('Wine sales')
pylab.show()
# Out:
# C:\Users\stesn\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
